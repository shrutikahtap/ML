# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import warnings
warnings.filterwarnings(action = 'ignore')

# %% [raw]
# Relation between the single independent variable and the target variable - A single graph can be used.
# As the number of independent variables increases, the dimensionality of the data increases and thus, visualization becomes tougher and tougher.

# %% [raw]
# Challenges of high dimensional data
# 01- VISUALIZATION
# 02- Importance of independent variables
# 03- Computational complexity
# 04- Model interpretability
# 05- Data exploration
#
# Dimensionality Reduction
# The process of reducing the number of variables from the data to ensure that the reduced data conveys maximum information.

# %% [raw]
# Feature Selection:
#    Common Dimensionality Reduction Techniques:
#            • Missing value ratio
#            • Low variance
#            • High correlation
#    Advanced Dimensionality Reduction Techniques:
#            • Backward feature elimination
#            • Forward feature selection

# %%
data = pd.read_csv("Transformed_Housing_Data2.csv")
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
data.head().shape
# Out:
# (5, 31)

# %%
data.isnull().sum()
# Out:
# Sale_Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# No of Times Visited                          0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# Years Since Renovation                       0
# Condition_of_the_House_Excellent             0
# Condition_of_the_House_Fair                  0
# Condition_of_the_House_Good                  0
# Condition_of_the_House_Okay                  0
# ...

# %%
data['No of Times Visited'] = np.where(data['No of Times Visited']==0, np.nan ,data['No of Times Visited'] )

# %%
data['No of Times Visited'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: No of Times Visited, dtype: float64

# %%
data['No of Times Visited'].isnull().sum()/len(data)
# Out:
# 0.9017076218242399

# %%
data['Years Since Renovation'].value_counts()
# Out:
# 0     20695
# 3        83
# 11       34
# 4        32
# 14       32
#       ...
# 58        1
# 70        1
# 55        1
# 65        1
# 69        1
# Name: Years Since Renovation, Length: 74, dtype: int64

# %%
data['Years Since Renovation'] = np.where(data['Years Since Renovation']==0, np.nan, data['Years Since Renovation'])
data['Years Since Renovation'].isnull().sum()
# Out:
# 20695

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                  NaN              7
# 1              7242.0           2.0                  NaN              7
# 2             10000.0           1.0                  NaN              6
# 3              5000.0           1.0                  NaN              7
# 4              8080.0           1.0                  NaN              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
data['Basement Area (in Sqft)'] = np.where( data['Basement Area (in Sqft)'] ==0 ,np.nan, data['Basement Area (in Sqft)'])
data['Basement Area (in Sqft)'].isnull().sum()
# Out:
# 13123

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                  NaN              7
# 1              7242.0           2.0                  NaN              7
# 2             10000.0           1.0                  NaN              6
# 3              5000.0           1.0                  NaN              7
# 4              8080.0           1.0                  NaN              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
data.to_csv("NaN_Housing_Prices.csv", index = False)

# %% [markdown]
# ## Actual Notebook starts here

# %%
data = pd.read_csv('NaN_Housing_Prices.csv')
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                  NaN              7
# 1              7242.0           2.0                  NaN              7
# 2             10000.0           1.0                  NaN              6
# 3              5000.0           1.0                  NaN              7
# 4              8080.0           1.0                  NaN              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
  data.head().shape
# Out:
# (5, 31)

# %%
data.isnull().sum()
# Out:
# Sale_Price                                       0
# No of Bedrooms                                   0
# No of Bathrooms                                  0
# Flat Area (in Sqft)                              0
# Lot Area (in Sqft)                               0
# No of Floors                                     0
# No of Times Visited                          19485
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        0
# Basement Area (in Sqft)                      13123
# Age of House (in Years)                          0
# Latitude                                         0
# Longitude                                        0
# Living Area after Renovation (in Sqft)           0
# Lot Area after Renovation (in Sqft)              0
# Years Since Renovation                       20695
# Condition_of_the_House_Excellent                 0
# Condition_of_the_House_Fair                      0
# ...

# %% [markdown]
# # MISSING VALUE RATIO

# %% [raw]
# Ratio of missing values= (Number of missing values)/(Total number of observations)
# Considering the fact that we have 28 independent variables which do not have any missing values and have a reasonably large number of observations.
#
# • Threshold missing value ratio = 0.70
# • If missing value ratio ≤ 0.70, then: the variable can be estimated
# • If missing value ratio > 0.70, then: the variable will be dropped
#
# Threshold for the missing value ratio may depend on:
# • The nature of the problem
# • The size of the dataset
# • Personal preference, etc.
#
# Missing value ratio is removing the features which have missing values beyond a certain threshold. PCA is transforming the features while retaining the maximum information. Forward feature selection is a technique.

# %%
'''MISSING VALUE RATIO'''

for i in data.columns:
  tmp = data[i].isnull().sum()/len(data)
  if tmp > 0.70:
    print("Removing column '"+i+"' with missing value ratio", tmp)
    data = data.drop(columns = [i])
# Out:
# Removing column 'No of Times Visited' with missing value ratio 0.9017076218242399
# Removing column 'Years Since Renovation' with missing value ratio 0.9577028090147623

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0              5650.0           1.0              7
# 1              7242.0           2.0              7
# 2             10000.0           1.0              6
# 3              5000.0           1.0              7
# 4              8080.0           1.0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                      NaN
# 1                                     2170.0                    400.0
# ...

# %%
data = pd.read_csv("Raw_Housing_Prices3.csv")
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %% [markdown]
# # LOW VARIANCE

# %% [raw]
# In predictive modelling, the independent variables with low variance are eliminated.
# We use the low variance filter :
# A. Variables with low variance do not contain any significant information
# B. They reduce the performance of the predictive model
# C. They decrease the effect of other independent variables

# %%
numerical_data = data.drop(columns = ['ID', 'Date House was Sold', 'Sale Price','Waterfront View', 'No of Times Visited',
                            'Condition of the House', 'Overall Grade', 'Zipcode'])
numerical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   No of Bedrooms                             21609 non-null  int64
#  1   No of Bathrooms                            21609 non-null  float64
#  2   Flat Area (in Sqft)                        21609 non-null  float64
#  3   Lot Area (in Sqft)                         21609 non-null  float64
#  4   No of Floors                               21609 non-null  float64
#  5   Area of the House from Basement (in Sqft)  21609 non-null  float64
#  6   Basement Area (in Sqft)                    21609 non-null  int64
#  7   Age of House (in Years)                    21609 non-null  int64
#  8   Renovated Year                             21609 non-null  int64
#  9   Latitude                                   21609 non-null  float64
# ...

# %% [raw]
# StandardScaler changes the variance to 1. Determining the minimum threshold of the variance
# Variance Threshold = 1e-04 = 0.0001
# On choosing a wrong threshold value, some important information might be missed.

# %%
from sklearn.preprocessing import Normalizer 
norm = Normalizer()
norm_data = norm.fit_transform(numerical_data)
norm_data = pd.DataFrame(norm_data, columns = numerical_data.columns)
norm_data.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0        0.000363         0.000121             0.142628            0.682924
# 1        0.000264         0.000198             0.226174            0.637335
# 2        0.000152         0.000076             0.058440            0.758961
# 3        0.000527         0.000395             0.258159            0.658569
# 4        0.000263         0.000175             0.147072            0.707346
#
#    No of Floors  Area of the House from Basement (in Sqft)  \
# 0      0.000121                                   0.142628
# 1      0.000176                                   0.190972
# 2      0.000076                                   0.058440
# 3      0.000132                                   0.138299
# 4      0.000088                                   0.147072
#
#    Basement Area (in Sqft)  Age of House (in Years)  Renovated Year  Latitude  \
# ...

# %%
tmp = norm_data.var()
tmp
# Out:
# No of Bedrooms                               4.071117e-08
# No of Bathrooms                              2.802492e-08
# Flat Area (in Sqft)                          1.231500e-02
# Lot Area (in Sqft)                           1.351803e-02
# No of Floors                                 3.008524e-08
# Area of the House from Basement (in Sqft)    1.010140e-02
# Basement Area (in Sqft)                      1.648493e-03
# Age of House (in Years)                      2.002344e-05
# Renovated Year                               1.684740e-03
# Latitude                                     1.077875e-05
# Longitude                                    7.109191e-05
# Living Area after Renovation (in Sqft)       1.079222e-02
# Lot Area after Renovation (in Sqft)          1.250016e-02
# dtype: float64

# %%
T = 1e-04
for i in tmp:
  if i < T:
    norm_data.drop(columns = [tmp[tmp ==i].index[0]], inplace = True)
norm_data.var()
# Out:
# Flat Area (in Sqft)                          0.012315
# Lot Area (in Sqft)                           0.013518
# Area of the House from Basement (in Sqft)    0.010101
# Basement Area (in Sqft)                      0.001648
# Renovated Year                               0.001685
# Living Area after Renovation (in Sqft)       0.010792
# Lot Area after Renovation (in Sqft)          0.012500
# dtype: float64

# %% [raw]
# Eliminating categorical variables:
# 1- Use the value counts function
# 2- Look at the frequency of distinct categories
# 3- If frequency is very high frequency (>95%), eliminate the variable
#
# Elimination of independent variables with high correlation:
# On the basis of high correlation
# • Not a reliable technique as it only looks at one to one correlation
# Variance Inflation Factor (VIF)
# • A reliable technique as it looks at things at an aggregate level

# %% [raw]
# Drawbacks of feature selection techniques like:
#     • Missing value ratio
#     • Low variance
#     • High correlation
# ARE:
# • Very subjective criteria for dimensionality reduction which can be a source of confusion.
# • Lead to poor model performance due to accidentally eliminating some important features.

# %% [markdown]
# # ADVANCED DIMENSIONALITY REDUCTION

# %%
data = pd.read_csv('Transformed_Housing_Data2.csv')
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %% [raw]
# R2:
# • It does not consider the number of input variables in the model.
# • The values keep on marginally increasing even if the newly added feature has zero to minimal importance.
# Adjusted R2:
#
# Adjusted R2 = 1- {[(n-1)*(1-R2)]/[n-(k+1)]}
# Where:
# • n represents the sample size or total number of observations.
# • k represents the number of input variables in our regression model.
# Use adjusted R2 if you are building a model on multiple variables.
#
# An evaluation metric governs whether any given feature should be selected in the final model or not.
# 1- The new feature added contributes significantly to model performance.
# 2- The new feature added does not contribute significantly to model performance.
#
# Adjusted R2 is inversely proportional to k

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Y = data['Sale_Price']
X = scaler.fit_transform(data.drop(columns = ['Sale_Price']))
X = pd.DataFrame(data = X, columns = data.drop(columns = ['Sale_Price']).columns)
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0       -0.398724        -1.447526            -0.979905           -0.228291
# 1       -0.398724         0.175684             0.533718           -0.189858
# 2       -1.474115        -1.447526            -1.426369           -0.123276
# 3        0.676667         1.149611            -0.130534           -0.243983
# 4       -0.398724        -0.148958            -0.435436           -0.169628
#
#    No of Floors  No of Times Visited  Overall Grade  \
# 0     -0.915389             -0.30579      -0.563993
# 1      0.936817             -0.30579      -0.563993
# 2     -0.915389             -0.30579      -1.468566
# 3     -0.915389             -0.30579      -0.563993
# 4     -0.915389             -0.30579       0.340581
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                  -0.734722                -0.658697
# ...

# %%
X = data.drop(columns = ["Sale_Price"])
Y = data['Sale_Price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 101)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((15126, 30), (6483, 30), (15126,), (6483,))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(x_test)

# %%
lr.score(x_test, y_test)
# Out:
# 0.8462355542468744

# %% [markdown]
# # FORWARD SELECTION

# %% [raw]
# Step 1:
# For every independent variable, build a linear regression model individually. Choose the independent variable with the highest adj- R ^ 2 score and call it Var1. Choose one independent variable from the complete set and use it to build a regression model and record the corresponding adj-R2 score.
#
# Step 2:
# Repeat the above process by using the Var1 as the base independent variable and combining it with every other independent variable to build a regression model. Choose the combination with highest adj- R ^ 2 score.Use a combination of all the remaining independent variables and the previously chosen independent variables and again choose the combination with the highest adj-R2 value.
#
# Step 3:
# Repeat the above process until the maximum number of features has been obtained or the adj- R ^ 2 score is no longer increasing.Repeat the process until the desired number of best features is obtained or until the adj-R2 value stops growing or starts reducing.

# %%
def adj_r2(m ,data_y, predictions):
  '''
  m : number of independent variables
  data_y : target variable
  predictions : prediction of the model to be evaluated
  Returns: Adjusted R²
  '''
  from sklearn.metrics import r2_score
  R = r2_score(data_y, predictions)
  n = len(data_y)
  adj_R = 1 - ((1-R)*(n-1))/(n-m-1)
  return adj_R

# %%
adj_r2(x_test,y_test,predictions)
# Out:
#        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 19827        0.846141         0.846176             0.742588
# 12528        0.846141         0.846188             0.729304
# 1611         0.846141         0.846176             0.746515
# 8686         0.846164         0.846194             0.773580
# 18204        0.846117         0.846158            -0.092874
# ...               ...              ...                  ...
# 10797        0.846141         0.846188             0.757612
# 13197        0.846141         0.846188             0.677652
# 1761         0.846141         0.846141             0.657726
# 5749         0.846117         0.846152             0.532504
# 11618        0.846117         0.846158             0.473202
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 19827           -0.083371      0.846188             0.846236       0.846022
# 12528            1.484306      0.846212             0.846236       0.846046
# ...

# %%
def return_r2(X, Y, model):
  '''
  X : independent variables
  Y : target variable
  model : predictive model
  Returns: Adjusted R² corresponding to the model
  '''
  model.fit(X, Y)
  pred = model.predict(X)
  m = len(X.columns)
  r2 = adj_r2(m, Y, pred)
  return r2

# %%
def forward_selection(model, X, Y, max_features):
  '''
  X : independent variables
  Y : target variable
  model : predictive model
  max_features : selects best feature upto max_features value
  Returns: 
  Rmax : Adjusted R2 of the final model
  history : list of Rmax at every new independent variable added to the model
  x[f_col] : best features upto max_features
  '''
  f_col = []
  history = []
  for i in range(max_features):
    f_col.append('blank')
    tmp = f_col[:]
    Rmax = -1
    for var in X.columns:
      tmp[-1] = var
      r2 = return_r2( X[tmp] , Y, model)
      if r2 >= Rmax:
        Rmax = r2
        f_col[-1] = var
        elim = var
    print("Selected",f_col[-1],"with new r2 =",Rmax)
    history.append(Rmax)
  return Rmax, history, X[f_col]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
score, history, sel_data = forward_selection(lr, x_train, y_train, 5)
# Out:
# Selected Flat Area (in Sqft) with new r2 = 0.4825106645259518
# Selected Latitude with new r2 = 0.6158682713046579
# Selected Overall Grade with new r2 = 0.6693250844517912
# Selected Age of House (in Years) with new r2 = 0.7101671809322653
# Selected Zipcode_Group_Zipcode_Group_8 with new r2 = 0.7359659801896957

# %%
sel_data.columns
# Out:
# Index(['Flat Area (in Sqft)', 'Latitude', 'Overall Grade',
#        'Age of House (in Years)', 'Zipcode_Group_Zipcode_Group_8'],
#       dtype='object')

# %%
score
# Out:
# 0.7359659801896957

# %% [markdown]
# # BACKWARD ELIMINATION

# %% [raw]
# Backward elimination is used to:
# • Remove the redundant variables from the model.
# • Strike a balance between the model performance and model simplicity.
#
# Step 1:
# Build a model with all the independent variables.
# Step 2:
# • Drop 1 independent variable at a time.
# • Repeat the process.
# • Calculate the corresponding adj-R2.
# • Repeat the process.
# Step 3:
# Subtract the baseline adj-R2 from all calculated adj-R2 and record the difference.
# Step 4:
# Make the maximum difference value as the new baseline adj-R2 and permanently drop the independent variable corresponding to it.
# Step 5:
# Repeat the process for the required number of times.

# %%
def adj_r2( m=0, data_y=0, predictions=0):
  '''
  m : number of independent variables
  data_y : target variable
  predictions : prediction of the model to be evaluated
  Returns: Adjusted R2
  '''
  from sklearn.metrics import r2_score
  R = r2_score(data_y, predictions)
  n = len(data_y)
  adj_R = 1 - ((1-R)*(n-1))/(n-m-1)
  return adj_R

# %%
def return_r2(X, Y, model):
  '''
  X : independent variables
  Y : target variable
  model : predictive model
  Returns: Adjusted R2 corresponding to the model
  '''
  model.fit(X, Y)
  pred = model.predict(X)
  m = len(X.columns)
  r2 = adj_r2(m, Y, pred)
  return r2

# %%
def backward_elimination( model, X, Y, min_features):
  '''
  X : independent variables
  Y : target variable
  model : predictive model
  min_features : eliminate worst features until only min_features are left
  Returns: 
  Rmax : Adjusted R2 of the final model
  history : list of Rmax at every new independent variable added to the model
  x[f_col] : best features upto max_features
  '''
  elim_data = X[:]
  r2_history = []
  base_r2 = return_r2(elim_data, Y, model)
  print("base_r2 is", base_r2)
  for i in range(X.shape[1] - min_features):
    difference = -100
    for var in elim_data.columns:
      tmp = elim_data.drop(columns = [var])
      r2 = return_r2(tmp, Y, model)
      if (r2 - base_r2) > difference:
        difference = r2 - base_r2
        eliminate = var
        new_r2 = r2
  
    elim_data.drop(columns = [eliminate], inplace = True)
    r2_history.append(new_r2)
    print(eliminate,"Eliminated : New adj_r2 = ",new_r2,)
    base_r2 = new_r2
  return base_r2, r2_history, elim_data

# %% [raw]
# What range of values can the difference between the calculated and the baseline adj-R2 take? And which one is more favorable?
#
# Case 1:
# Calculated adj-R2 - baseline adj-R2 > 0
# Dropping that corresponding variable actually improved the model.
#
# Case 2:
# Calculated adj-R2 - baseline adj-R2 < 0
# The removal of the independent variable decreases the model performance - A good point to stop the backward elimination.

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

score , history, survided_data = backward_elimination(lr, x_train, y_train, 1)
# Out:
# base_r2 is 0.8411713183817104
# Area of the House from Basement (in Sqft) Eliminated : New adj_r2 =  0.841179744665843
# Condition_of_the_House_Okay Eliminated : New adj_r2 =  0.8411623663620638
# No of Floors Eliminated : New adj_r2 =  0.8411171250786782
# Lot Area after Renovation (in Sqft) Eliminated : New adj_r2 =  0.8410610037918913
# No of Bedrooms Eliminated : New adj_r2 =  0.8409159992800564
# Condition_of_the_House_Fair Eliminated : New adj_r2 =  0.8407704362899259
# Condition_of_the_House_Good Eliminated : New adj_r2 =  0.8404605503169833
# Years Since Renovation Eliminated : New adj_r2 =  0.8399491254999183
# Ever_Renovated_Yes Eliminated : New adj_r2 =  0.8394089149738739
# No of Bathrooms Eliminated : New adj_r2 =  0.8384257980145959
# Living Area after Renovation (in Sqft) Eliminated : New adj_r2 =  0.837125308901623
# Waterfront_View_Yes Eliminated : New adj_r2 =  0.8356698063157928
# Zipcode_Group_Zipcode_Group_1 Eliminated : New adj_r2 =  0.8339600690154836
# ...

# %%
history
# Out:
# [0.841179744665843,
#  0.8411623663620638,
#  0.8411171250786782,
#  0.8410610037918913,
#  0.8409159992800564,
#  0.8407704362899259,
#  0.8404605503169833,
#  0.8399491254999183,
#  0.8394089149738739,
#  0.8384257980145959,
#  0.837125308901623,
#  0.8356698063157928,
#  0.8339600690154836,
#  0.8318506623682476,
#  0.8295620645811876,
#  0.8266049066242156,
#  0.8242921707826699,
#  0.8192910381878411,
#  0.813501372362812,
#  0.7999680310309634,
#  0.7819399099884954,
#  0.770302160770225,
#  0.7580319410320749,
#  0.745451210409211,
#  0.7245993616828927,
#  0.7001983572378965,
#  0.669325084451791,
#  0.6158682713046579,
#  0.4825106645259518]

# %%
plt.figure(figsize = (12,3), dpi = 150)
plt.plot(range(len(history),0,-1), history, color = 'red')
plt.xlabel('remaining features')
plt.ylabel('adj-R2 Score')
#plt.yticks([z/100 for z in range()])
plt.title('Backward Elimination')
# Out:
# Text(0.5, 1.0, 'Backward Elimination')
