# %% [markdown]
# # Pre defined functions

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
array=[2,4,5,8,7,56,21,12]
np.sum(array)
# Out:
# 115

# %%
np.max(array)
# Out:
# 56

# %%
np.min(array)
# Out:
# 2

# %% [markdown]
# # User defined functions

# %%
def factorial(n):
    fact = 1
    for num in range(2, n + 1):
        fact *= num
    return fact

b=factorial(4)
print(b)
# Out:
# 24

# %% [markdown]
# # More on pre defined functions

# %%
data=pd.read_csv('Housing.csv')

# %%
data.head()
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  7420         4          2        3      yes        no       no
# 1  8960         4          4        4      yes        no       no
# 2  9960         3          2        2      yes        no      yes
# 3  7500         4          2        2      yes        no      yes
# 4  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating  parking prefarea furnishingstatus airconditioning     price
# 0              no        2      yes        furnished             yes  13300000
# 1              no        3       no        furnished             yes  12250000
# 2              no        2      yes   semi-furnished              no  12250000
# 3              no        3      yes        furnished             yes  12215000
# 4              no        2       no        furnished             yes  11410000

# %%
data.dtypes
# Out:
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# airconditioning     object
# price                int64
# dtype: object

# %%
data.head(12)
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# 5    7500         3          3        1      yes        no      yes
# 6    8580         4          3        4      yes        no       no
# 7   16200         5          3        2      yes        no       no
# 8    8100         4          1        2      yes       yes      yes
# 9    5750         3          2        4      yes       yes       no
# 10  13200         3          1        2      yes        no      yes
# 11   6000         4          3        2      yes       yes      yes
#
#    hotwaterheating  parking prefarea furnishingstatus airconditioning  \
# ...

# %%
data.tail(12)
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 533  2400         3          1        2      yes        no       no
# 534  3000         4          1        2      yes        no       no
# 535  3360         2          1        1      yes        no       no
# 536  3420         5          1        2       no        no       no
# 537  1700         3          1        2      yes        no       no
# 538  3649         2          1        1      yes        no       no
# 539  2990         2          1        1       no        no       no
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating  parking prefarea furnishingstatus airconditioning  \
# ...

# %% [markdown]
# # Descriptive statistics

# %%
data.describe()
# Out:
#                area    bedrooms   bathrooms     stories     parking  \
# count    545.000000  545.000000  545.000000  545.000000  545.000000
# mean    5150.541284    2.965138    1.286239    1.805505    0.693578
# std     2170.141023    0.738064    0.502470    0.867492    0.861586
# min     1650.000000    1.000000    1.000000    1.000000    0.000000
# 25%     3600.000000    2.000000    1.000000    1.000000    0.000000
# 50%     4600.000000    3.000000    1.000000    2.000000    0.000000
# 75%     6360.000000    3.000000    2.000000    2.000000    1.000000
# max    16200.000000    6.000000    4.000000    4.000000    3.000000
#
#               price
# count  5.450000e+02
# mean   4.766729e+06
# std    1.870440e+06
# min    1.750000e+06
# 25%    3.430000e+06
# 50%    4.340000e+06
# 75%    5.740000e+06
# max    1.330000e+07

# %%
data.describe(include='all')
# Out:
#                 area    bedrooms   bathrooms     stories mainroad guestroom  \
# count     545.000000  545.000000  545.000000  545.000000      545       545
# unique           NaN         NaN         NaN         NaN        2         2
# top              NaN         NaN         NaN         NaN      yes        no
# freq             NaN         NaN         NaN         NaN      468       448
# mean     5150.541284    2.965138    1.286239    1.805505      NaN       NaN
# std      2170.141023    0.738064    0.502470    0.867492      NaN       NaN
# min      1650.000000    1.000000    1.000000    1.000000      NaN       NaN
# 25%      3600.000000    2.000000    1.000000    1.000000      NaN       NaN
# 50%      4600.000000    3.000000    1.000000    2.000000      NaN       NaN
# 75%      6360.000000    3.000000    2.000000    2.000000      NaN       NaN
# max     16200.000000    6.000000    4.000000    4.000000      NaN       NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   area              545 non-null    int64
#  1   bedrooms          545 non-null    int64
#  2   bathrooms         545 non-null    int64
#  3   stories           545 non-null    int64
#  4   mainroad          545 non-null    object
#  5   guestroom         545 non-null    object
#  6   basement          545 non-null    object
#  7   hotwaterheating   545 non-null    object
#  8   parking           545 non-null    int64
#  9   prefarea          545 non-null    object
#  10  furnishingstatus  545 non-null    object
#  11  airconditioning   545 non-null    object
#  12  price             545 non-null    int64
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
data.mean()
# Out:
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# price        4.766729e+06
# dtype: float64

# %%
data.min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating  parking prefarea furnishingstatus airconditioning  \
# ...

# %%
data.std()
# Out:
# area         2.170141e+03
# bedrooms     7.380639e-01
# bathrooms    5.024696e-01
# stories      8.674925e-01
# parking      8.615858e-01
# price        1.870440e+06
# dtype: float64

# %%
data['bedrooms'].mean()
# Out:
# 2.9651376146788992

# %%
data['bedrooms'].std()
# Out:
# 0.738063860568575

# %%
data.quantile(.25)
# Out:
# area            3600.0
# bedrooms           2.0
# bathrooms          1.0
# stories            1.0
# parking            0.0
# price        3430000.0
# Name: 0.25, dtype: float64

# %%
data.quantile(0.50)
# Out:
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# price        4340000.0
# Name: 0.5, dtype: float64

# %%
data.quantile(0.75)
# Out:
# area            6360.0
# bedrooms           3.0
# bathrooms          2.0
# stories            2.0
# parking            1.0
# price        5740000.0
# Name: 0.75, dtype: float64

# %%
data['area'].quantile(0.25)
# Out:
# 3600.0

# %%
data['bedrooms'].unique()
# Out:
# array([4, 3, 5, 2, 6, 1], dtype=int64)

# %%
data['airconditioning'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
import numpy as np

# %%
np.std(data['area'])
# Out:
# 2168.1491533213048

# %%
data['area'].std()
# Out:
# 2170.141022508803

# %% [markdown]
# both the standard deviation differ from each other through different methods as they follow different formulas

# %%
data['area'].std() - np.std(data['area'])
# Out:
# 1.991869187498196

# %%
np.std(data['area'],ddof=1)
# Out:
# 2170.141022508803

# %%
dir(np)                            #list of all the functions
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_CopyMode',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__deprecated_attrs__',
#  '__dir__',
#  '__doc__',
# ...

# %% [markdown]
# # Plotting the graphs

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data['area'])                            #line graph

# %%
plt.plot(data['bedrooms'])

# %%
plt.plot(data['bedrooms'], color='pink')

# %%
plt.plot(data['area'],color='orange',marker="*",markerfacecolor="green",markersize="10",linewidth='2',linestyle="dashed")
plt.xlabel("Room Number")
plt.ylabel("Area in square meter")
plt.title("Not my graph")
plt.show()

# %%
data.groupby("bedrooms").count()
# Out:
#           area  bathrooms  stories  mainroad  guestroom  basement  \
# bedrooms
# 1            2          2        2         2          2         2
# 2          136        136      136       136        136       136
# 3          300        300      300       300        300       300
# 4           95         95       95        95         95        95
# 5           10         10       10        10         10        10
# 6            2          2        2         2          2         2
#
#           hotwaterheating  parking  prefarea  furnishingstatus  \
# bedrooms
# 1                       2        2         2                 2
# 2                     136      136       136               136
# 3                     300      300       300               300
# 4                      95       95        95                95
# 5                      10       10        10                10
# 6                       2        2         2                 2
#
#           airconditioning  price
# ...

# %%
data.groupby("bedrooms")['price'].count()
# Out:
# bedrooms
# 1      2
# 2    136
# 3    300
# 4     95
# 5     10
# 6      2
# Name: price, dtype: int64

# %%
values=(1,2,3,4,5,6)

# %%
labels=(2,136,300,95,10,2)

# %%
plt.pie(values,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x27a07851ad0>,
# ...
#  [Text(1.087713908390803, 0.16394649582471824, '2'),
#   Text(0.9088626448409262, 0.6196520740002058, '136'),
#   Text(0.2447729879062314, 1.0724207124032321, '300'),
#   Text(-0.8063571098828889, 0.7481899567231004, '95'),
#   Text(-0.9088626013289132, -0.6196521378206009, '10'),
#   Text(0.6858388884465332, -0.8600145458621175, '2')])

# %%
plt.bar(labels,values,color="red",linewidth='10',linestyle='dashed')
plt.xlabel("prices maybe")
plt.ylabel("bedrooms number maybe")
plt.title("Mine Maybe")
plt.show()

# %%
plt.scatter(x=data['area'],y=data['price'],color='red')
plt.xlabel('area of the house')
plt.ylabel('price of the house')
plt.title("Maidaan ae jangh")
plt.show()

# %%
data.describe()
# Out:
#                area    bedrooms   bathrooms     stories     parking  \
# count    545.000000  545.000000  545.000000  545.000000  545.000000
# mean    5150.541284    2.965138    1.286239    1.805505    0.693578
# std     2170.141023    0.738064    0.502470    0.867492    0.861586
# min     1650.000000    1.000000    1.000000    1.000000    0.000000
# 25%     3600.000000    2.000000    1.000000    1.000000    0.000000
# 50%     4600.000000    3.000000    1.000000    2.000000    0.000000
# 75%     6360.000000    3.000000    2.000000    2.000000    1.000000
# max    16200.000000    6.000000    4.000000    4.000000    3.000000
#
#               price
# count  5.450000e+02
# mean   4.766729e+06
# std    1.870440e+06
# min    1.750000e+06
# 25%    3.430000e+06
# 50%    4.340000e+06
# 75%    5.740000e+06
# max    1.330000e+07

# %%
data2=pd.read_csv("housingprices.csv")

# %%
data2.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
data2.info
# Out:
# <bound method DataFrame.info of                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# ...

# %%
plt.hist(data['bedrooms'],bins=10)
# Out:
# (array([  2.,   0., 136.,   0., 300.,   0.,  95.,   0.,  10.,   2.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data2['Age of House (in Years)'],bins=15,color='yellow')
plt.xlabel('years')
plt.ylabel('area of the house')
plt.title('kuch toh hai')
plt.show()

# %%
plt.boxplot(data['bedrooms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27a0bc26c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27a0e178990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27a05a1fd10>],
#  'medians': [<matplotlib.lines.Line2D at 0x27a0e17afd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27a09251090>],
#  'means': []}
